# %%
from pyspark.sql import SparkSession, Row
from pyspark.sql import SparkSession
from pyspark.mllib.stat import Statistics
from pydeequ.analyzers import *
from pydeequ.checks import *
from pydeequ.profiles import *
from pydeequ.suggestions import *
from pydeequ.verification import *
from pyspark.sql.functions import *
import pydeequ
import pandas as pd
from jinja2 import Template


# create a SparkSession object
spark = SparkSession.builder.appName("PyDeequ")\
.config("spark.jars", "/home/jovyan/work/enu/mssql-jdbc-12.2.0.jre8.jar")\
.config('spark.driver.extraClassPath', '/home/jovyan/work/enu/mssql-jdbc-12.2.0.jre8.jar')\
.config('spark.executor.extraClassPath', '/home/jovyan/work/enu/mssql-jdbc-12.2.0.jre8.jar')\
.config("spark.jars.packages", pydeequ.deequ_maven_coord)\
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)\
.getOrCreate()
jars = spark.conf.get("spark.driver.extraClassPath")

# %%
# connect to the SQL Server database
jdbcHostname = r"EPPLWARW01DC\SQLEXPRESS"
jdbcDatabase = "AdventureWorks2012"
jdbcPort = 1433
username = "test_user"
password = "test_user"
jdbcUrl = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname, jdbcPort, jdbcDatabase)
connectionProperties = {
      "user" : username,
      "password" : password,
      "driver" : "com.microsoft.sqlserver.jdbc.SQLServerDriver",
      "encrypt": "false",
}

# read data from a table
df = spark.read.jdbc(url=jdbcUrl, table="Production.Product", properties=connectionProperties)

# %%
# perform data analyzing
analysisResult = AnalysisRunner(spark) \
                .onData(df) \
                .addAnalyzer(Size()) \
                .addAnalyzer(Completeness("ProductID")) \
                .addAnalyzer(ApproxCountDistinct("ProductID")) \
                .addAnalyzer(Mean("ListPrice")) \
                .addAnalyzer(Compliance("top ListPrice", "ListPrice >= 10.0")) \
                .addAnalyzer(Correlation("SafetyStockLevel", "ReorderPoint")) \
.run()

analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show()
# Out:
# +-----------+--------------------+-------------------+------------------+
# |     entity|            instance|               name|             value|
# +-----------+--------------------+-------------------+------------------+
# |     Column|       top ListPrice|         Compliance|0.5773809523809523|
# |     Column|           ListPrice|               Mean|         438.66625|
# |    Dataset|                   *|               Size|             504.0|
# |     Column|           ProductID|       Completeness|               1.0|
# |     Column|           ProductID|ApproxCountDistinct|             510.0|
# |Mutlicolumn|SafetyStockLevel,...|        Correlation|1.0000000000000009|
# +-----------+--------------------+-------------------+------------------+

# %%
# perform data profiling
result = ColumnProfilerRunner(spark) \
    .onData(df) \
    .run()

# print readable profiling results 
for col, profile in result.profiles.items():
    print(f"Column: {col}")
    if hasattr(profile, 'dataType'):
        print(f"Data type: {profile.dataType}")
    if hasattr(profile, 'completeness'):
        print(f"Completeness: {profile.completeness}")
    if hasattr(profile, 'approximateNumDistinctValues') and hasattr(profile, 'numDistinctValues') :
        print(f"Distinctness: {profile.approximateNumDistinctValues}/{profile.numDistinctValues}")
    if hasattr(profile, 'minimum'):
        print(f"Min value: {profile.minimum}")
    if hasattr(profile, 'maximum'):
        print(f"Max value: {profile.maximum}")
    if hasattr(profile, 'mean'):
        print(f"Mean: {profile.mean}")
    if hasattr(profile, 'standardDeviation'):
        print(f"Standard deviation: {profile.standardDeviation}")
    if hasattr(profile, 'histogram'):
        print(f"Histogram: {profile.histogram}")
    if hasattr(profile, 'correlation'):
        print(f"Correlation: {profile.correlation}")
    print()
# Out:
# Column: ModifiedDate
# Data type: String
# Completeness: 1.0
# Histogram: None
#
# Column: ReorderPoint
# Data type: Integral
# Completeness: 1.0
# Min value: 3.0
# Max value: 750.0
# Mean: 401.36309523809524
# Histogram: [DistributionValue(value='45', count=5, ratio=0.00992063492063492), DistributionValue(value='750', count=156, ratio=0.30952380952380953), DistributionValue(value='375', count=167, ratio=0.33134920634920634), DistributionValue(value='75', count=97, ratio=0.19246031746031747), DistributionValue(value='600', count=25, ratio=0.0496031746031746), DistributionValue(value='3', count=54, ratio=0.10714285714285714)]
#
# Column: ProductLine
# Data type: String
# Completeness: 0.5515873015873016
# Histogram: [DistributionValue(value='NullValue', count=226, ratio=0.44841269841269843), DistributionValue(value='R ', count=100, ratio=0.1984126984126984), DistributionValue(value='M ', count=91, ratio=0.18055555555555555), DistributionValue(value='S ', count=35, ratio=0.06944444444444445), DistributionValue(value='T ', count=52, ratio=0.10317460317460317)]
#
# Column: Name
# Data type: String
# Completeness: 1.0
# Histogram: None
#
# Column: rowguid
# Data type: String
# Completeness: 1.0
# Histogram: None
#
# Column: SizeUnitMeasureCode
# Data type: String
# Completeness: 0.3492063492063492
# Histogram: [DistributionValue(value='NullValue', count=328, ratio=0.6507936507936508), DistributionValue(value='CM ', count=176, ratio=0.3492063492063492)]
#
# Column: SafetyStockLevel
# Data type: Integral
# Completeness: 1.0
# Min value: 4.0
# Max value: 1000.0
# Mean: 535.1507936507936
# Histogram: [DistributionValue(value='100', count=97, ratio=0.19246031746031747), DistributionValue(value='4', count=54, ratio=0.10714285714285714), DistributionValue(value='500', count=167, ratio=0.33134920634920634), DistributionValue(value='60', count=5, ratio=0.00992063492063492), DistributionValue(value='800', count=25, ratio=0.0496031746031746), DistributionValue(value='1000', count=156, ratio=0.30952380952380953)]
#
# Column: ListPrice
# Data type: Fractional
# Completeness: 1.0
# Min value: 0.0
# Max value: 3578.27
# Mean: 438.66624999999937
# Histogram: None
#
# Column: Size
# Data type: String
# Completeness: 0.41865079365079366
# Histogram: [DistributionValue(value='62', count=11, ratio=0.021825396825396824), DistributionValue(value='40', count=11, ratio=0.021825396825396824), DistributionValue(value='NullValue', count=293, ratio=0.5813492063492064), DistributionValue(value='44', count=29, ratio=0.057539682539682536), DistributionValue(value='XL', count=3, ratio=0.005952380952380952), DistributionValue(value='56', count=2, ratio=0.003968253968253968), DistributionValue(value='50', count=9, ratio=0.017857142857142856), DistributionValue(value='46', count=11, ratio=0.021825396825396824), DistributionValue(value='M', count=11, ratio=0.021825396825396824), DistributionValue(value='48', count=25, ratio=0.0496031746031746), DistributionValue(value='54', count=9, ratio=0.017857142857142856), DistributionValue(value='L', count=11, ratio=0.021825396825396824), DistributionValue(value='60', count=11, ratio=0.021825396825396824), DistributionValue(value='58', count=15, ratio=0.02976190476190476), DistributionValue(value='42', count=15, ratio=0.02976190476190476), DistributionValue(value='70', count=1, ratio=0.001984126984126984), DistributionValue(value='38', count=12, ratio=0.023809523809523808), DistributionValue(value='52', count=16, ratio=0.031746031746031744), DistributionValue(value='S', count=9, ratio=0.017857142857142856)]
#
# Column: DaysToManufacture
# Data type: Integral
# Completeness: 1.0
# Min value: 0.0
# Max value: 4.0
# Mean: 1.1031746031746033
# Histogram: [DistributionValue(value='2', count=7, ratio=0.013888888888888888), DistributionValue(value='1', count=154, ratio=0.3055555555555556), DistributionValue(value='4', count=97, ratio=0.19246031746031747), DistributionValue(value='0', count=246, ratio=0.4880952380952381)]
#
# Column: SellStartDate
# Data type: String
# Completeness: 1.0
# Histogram: None
#
# Column: MakeFlag
# Data type: Boolean
# Completeness: 1.0
# Histogram: [DistributionValue(value='false', count=265, ratio=0.5257936507936508), DistributionValue(value='true', count=239, ratio=0.4742063492063492)]
#
# Column: ProductSubcategoryID
# Data type: Integral
# Completeness: 0.5853174603174603
# Min value: 1.0
# Max value: 37.0
# Mean: 12.294915254237289
# Histogram: [DistributionValue(value='34', count=1, ratio=0.001984126984126984), DistributionValue(value='12', count=28, ratio=0.05555555555555555), DistributionValue(value='8', count=3, ratio=0.005952380952380952), DistributionValue(value='19', count=1, ratio=0.001984126984126984), DistributionValue(value='23', count=4, ratio=0.007936507936507936), DistributionValue(value='4', count=8, ratio=0.015873015873015872), DistributionValue(value='15', count=9, ratio=0.017857142857142856), DistributionValue(value='11', count=3, ratio=0.005952380952380952), DistributionValue(value='9', count=2, ratio=0.003968253968253968), DistributionValue(value='NullValue', count=209, ratio=0.4146825396825397), DistributionValue(value='33', count=3, ratio=0.005952380952380952), DistributionValue(value='22', count=7, ratio=0.013888888888888888), DistributionValue(value='26', count=1, ratio=0.001984126984126984), DistributionValue(value='37', count=11, ratio=0.021825396825396824), DistributionValue(value='13', count=7, ratio=0.013888888888888888), DistributionValue(value='24', count=3, ratio=0.005952380952380952), DistributionValue(value='35', count=1, ratio=0.001984126984126984), DistributionValue(value='16', count=18, ratio=0.03571428571428571), DistributionValue(value='5', count=3, ratio=0.005952380952380952), DistributionValue(value='10', count=3, ratio=0.005952380952380952), DistributionValue(value='21', count=8, ratio=0.015873015873015872), DistributionValue(value='32', count=1, ratio=0.001984126984126984), DistributionValue(value='6', count=2, ratio=0.003968253968253968), DistributionValue(value='36', count=2, ratio=0.003968253968253968), DistributionValue(value='1', count=32, ratio=0.06349206349206349), DistributionValue(value='17', count=14, ratio=0.027777777777777776), DistributionValue(value='25', count=3, ratio=0.005952380952380952), DistributionValue(value='14', count=33, ratio=0.06547619047619048), DistributionValue(value='31', count=3, ratio=0.005952380952380952), DistributionValue(value='20', count=6, ratio=0.011904761904761904), DistributionValue(value='27', count=1, ratio=0.001984126984126984), DistributionValue(value='2', count=43, ratio=0.08531746031746032), DistributionValue(value='18', count=3, ratio=0.005952380952380952), DistributionValue(value='30', count=1, ratio=0.001984126984126984), DistributionValue(value='7', count=1, ratio=0.001984126984126984), DistributionValue(value='29', count=1, ratio=0.001984126984126984), DistributionValue(value='3', count=22, ratio=0.04365079365079365), DistributionValue(value='28', count=3, ratio=0.005952380952380952)]
#
# Column: Weight
# Data type: Fractional
# Completeness: 0.40674603174603174
# Min value: 2.12
# Max value: 1050.0
# Mean: 74.06921951219512
# Histogram: None
#
# Column: WeightUnitMeasureCode
# Data type: String
# Completeness: 0.40674603174603174
# Histogram: [DistributionValue(value='G  ', count=29, ratio=0.057539682539682536), DistributionValue(value='NullValue', count=299, ratio=0.5932539682539683), DistributionValue(value='LB ', count=176, ratio=0.3492063492063492)]
#
# Column: ProductNumber
# Data type: String
# Completeness: 1.0
# Histogram: None
#
# Column: FinishedGoodsFlag
# Data type: Boolean
# Completeness: 1.0
# Histogram: [DistributionValue(value='false', count=209, ratio=0.4146825396825397), DistributionValue(value='true', count=295, ratio=0.5853174603174603)]
#
# Column: Class
# Data type: String
# Completeness: 0.49007936507936506
# Histogram: [DistributionValue(value='NullValue', count=257, ratio=0.5099206349206349), DistributionValue(value='M ', count=68, ratio=0.1349206349206349), DistributionValue(value='H ', count=82, ratio=0.1626984126984127), DistributionValue(value='L ', count=97, ratio=0.19246031746031747)]
#
# Column: ProductModelID
# Data type: Integral
# Completeness: 0.5853174603174603
# Min value: 1.0
# Max value: 128.0
# Mean: 37.44406779661017
# Histogram: [DistributionValue(value='45', count=1, ratio=0.001984126984126984), DistributionValue(value='98', count=1, ratio=0.001984126984126984), DistributionValue(value='113', count=1, ratio=0.001984126984126984), DistributionValue(value='34', count=8, ratio=0.015873015873015872), DistributionValue(value='67', count=1, ratio=0.001984126984126984), DistributionValue(value='120', count=1, ratio=0.001984126984126984), DistributionValue(value='93', count=1, ratio=0.001984126984126984), DistributionValue(value='12', count=3, ratio=0.005952380952380952), DistributionValue(value='66', count=1, ratio=0.001984126984126984), DistributionValue(value='89', count=1, ratio=0.001984126984126984), DistributionValue(value='51', count=1, ratio=0.001984126984126984), DistributionValue(value='124', count=1, ratio=0.001984126984126984), DistributionValue(value='84', count=1, ratio=0.001984126984126984), DistributionValue(value='8', count=10, ratio=0.01984126984126984), DistributionValue(value='78', count=1, ratio=0.001984126984126984), DistributionValue(value='19', count=8, ratio=0.015873015873015872), DistributionValue(value='100', count=1, ratio=0.001984126984126984), DistributionValue(value='23', count=10, ratio=0.01984126984126984), DistributionValue(value='62', count=1, ratio=0.001984126984126984), DistributionValue(value='128', count=1, ratio=0.001984126984126984), DistributionValue(value='4', count=3, ratio=0.005952380952380952), DistributionValue(value='121', count=1, ratio=0.001984126984126984), DistributionValue(value='88', count=1, ratio=0.001984126984126984), DistributionValue(value='77', count=1, ratio=0.001984126984126984), DistributionValue(value='110', count=1, ratio=0.001984126984126984), DistributionValue(value='15', count=5, ratio=0.00992063492063492), DistributionValue(value='11', count=4, ratio=0.007936507936507936), DistributionValue(value='104', count=1, ratio=0.001984126984126984), DistributionValue(value='90', count=1, ratio=0.001984126984126984), DistributionValue(value='9', count=12, ratio=0.023809523809523808), DistributionValue(value='NullValue', count=209, ratio=0.4146825396825397), DistributionValue(value='44', count=1, ratio=0.001984126984126984), DistributionValue(value='33', count=3, ratio=0.005952380952380952), DistributionValue(value='117', count=1, ratio=0.001984126984126984), DistributionValue(value='22', count=4, ratio=0.007936507936507936), DistributionValue(value='56', count=1, ratio=0.001984126984126984), DistributionValue(value='55', count=1, ratio=0.001984126984126984), DistributionValue(value='26', count=8, ratio=0.015873015873015872), DistributionValue(value='50', count=1, ratio=0.001984126984126984), DistributionValue(value='123', count=1, ratio=0.001984126984126984), DistributionValue(value='37', count=3, ratio=0.005952380952380952), DistributionValue(value='68', count=1, ratio=0.001984126984126984), DistributionValue(value='61', count=1, ratio=0.001984126984126984), DistributionValue(value='107', count=1, ratio=0.001984126984126984), DistributionValue(value='13', count=4, ratio=0.007936507936507936), DistributionValue(value='46', count=1, ratio=0.001984126984126984), DistributionValue(value='99', count=1, ratio=0.001984126984126984), DistributionValue(value='24', count=2, ratio=0.003968253968253968), DistributionValue(value='94', count=1, ratio=0.001984126984126984), DistributionValue(value='83', count=1, ratio=0.001984126984126984), DistributionValue(value='35', count=4, ratio=0.007936507936507936), DistributionValue(value='16', count=5, ratio=0.00992063492063492), DistributionValue(value='79', count=1, ratio=0.001984126984126984), DistributionValue(value='5', count=10, ratio=0.01984126984126984), DistributionValue(value='103', count=1, ratio=0.001984126984126984), DistributionValue(value='112', count=1, ratio=0.001984126984126984), DistributionValue(value='10', count=10, ratio=0.01984126984126984), DistributionValue(value='59', count=1, ratio=0.001984126984126984), DistributionValue(value='87', ...
#
# Column: DiscontinuedDate
# Data type: String
# Completeness: 0.0
# Histogram: None
#
# Column: Style
# Data type: String
# Completeness: 0.41865079365079366
# Histogram: [DistributionValue(value='U ', count=176, ratio=0.3492063492063492), DistributionValue(value='W ', count=28, ratio=0.05555555555555555), DistributionValue(value='NullValue', count=293, ratio=0.5813492063492064), DistributionValue(value='M ', count=7, ratio=0.013888888888888888)]
#
# Column: ProductID
# Data type: Integral
# Completeness: 1.0
# Min value: 1.0
# Max value: 999.0
# Mean: 673.0396825396825
# Histogram: None
#
# Column: Color
# Data type: String
# Completeness: 0.5079365079365079
# Histogram: [DistributionValue(value='Yellow', count=36, ratio=0.07142857142857142), DistributionValue(value='NullValue', count=248, ratio=0.49206349206349204), DistributionValue(value='Multi', count=8, ratio=0.015873015873015872), DistributionValue(value='Red', count=38, ratio=0.07539682539682539), DistributionValue(value='Blue', count=26, ratio=0.051587301587301584), DistributionValue(value='White', count=4, ratio=0.007936507936507936), DistributionValue(value='Black', count=93, ratio=0.18452380952380953), DistributionValue(value='Grey', count=1, ratio=0.001984126984126984), DistributionValue(value='Silver/Black', count=7, ratio=0.013888888888888888), DistributionValue(value='Silver', count=43, ratio=0.08531746031746032)]
#
# Column: SellEndDate
# Data type: String
# Completeness: 0.19444444444444445
# Histogram: None
#
# Column: StandardCost
# Data type: Fractional
# Completeness: 1.0
# Min value: 0.0
# Max value: 2171.2942
# Mean: 258.60296130952383
# Histogram: None

# %%
# suggest constraints
suggestionResult = ConstraintSuggestionRunner(spark) \
                        .onData(df) \
                        .addConstraintRule(DEFAULT()) \
                        .run()

#print(json.dumps(suggestionResult, indent=2))
# print constraint suggestions
for suggestion in suggestionResult['constraint_suggestions']:
    print(str(suggestion['constraint_name']) , str(suggestion['column_name']))
# Out:
# CompletenessConstraint(Completeness(ModifiedDate,None)) ModifiedDate
# ComplianceConstraint(Compliance('ReorderPoint' has value range '375', '750', '75', '3', '600', '45',`ReorderPoint` IN ('375', '750', '75', '3', '600', '45'),None)) ReorderPoint
# CompletenessConstraint(Completeness(ReorderPoint,None)) ReorderPoint
# ComplianceConstraint(Compliance('ReorderPoint' has value range '375', '750', '75', '3' for at least 91.0% of values,`ReorderPoint` IN ('375', '750', '75', '3'),None)) ReorderPoint
# ComplianceConstraint(Compliance('ReorderPoint' has no negative values,ReorderPoint >= 0,None)) ReorderPoint
# ComplianceConstraint(Compliance('ProductLine' has value range 'R ', 'M ', 'T ', 'S ',`ProductLine` IN ('R ', 'M ', 'T ', 'S '),None)) ProductLine
# ComplianceConstraint(Compliance('ProductLine' has value range 'R ', 'M ', 'T ' for at least 90.0% of values,`ProductLine` IN ('R ', 'M ', 'T '),None)) ProductLine
# CompletenessConstraint(Completeness(ProductLine,None)) ProductLine
# CompletenessConstraint(Completeness(Name,None)) Name
# UniquenessConstraint(Uniqueness(List(Name),None)) Name
# CompletenessConstraint(Completeness(rowguid,None)) rowguid
# UniquenessConstraint(Uniqueness(List(rowguid),None)) rowguid
# ComplianceConstraint(Compliance('SizeUnitMeasureCode' has value range 'CM ',`SizeUnitMeasureCode` IN ('CM '),None)) SizeUnitMeasureCode
# CompletenessConstraint(Completeness(SizeUnitMeasureCode,None)) SizeUnitMeasureCode
# ComplianceConstraint(Compliance('SafetyStockLevel' has value range '500', '1000', '100', '4', '800', '60',`SafetyStockLevel` IN ('500', '1000', '100', '4', '800', '60'),None)) SafetyStockLevel
# CompletenessConstraint(Completeness(SafetyStockLevel,None)) SafetyStockLevel
# ComplianceConstraint(Compliance('SafetyStockLevel' has value range '500', '1000', '100', '4' for at least 91.0% of values,`SafetyStockLevel` IN ('500', '1000', '100', '4'),None)) SafetyStockLevel
# ComplianceConstraint(Compliance('SafetyStockLevel' has no negative values,SafetyStockLevel >= 0,None)) SafetyStockLevel
# CompletenessConstraint(Completeness(ListPrice,None)) ListPrice
# ComplianceConstraint(Compliance('ListPrice' has no negative values,ListPrice >= 0,None)) ListPrice
# ComplianceConstraint(Compliance('Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40', '62', 'S', '54', '50', 'XL', '56', '70',`Size` IN ('44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40', '62', 'S', '54', '50', 'XL', '56', '70'),None)) Size
# ComplianceConstraint(Compliance('Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40' for at least 88.0% of values,`Size` IN ('44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40'),None)) Size
# CompletenessConstraint(Completeness(Size,None)) Size
# ComplianceConstraint(Compliance('DaysToManufacture' has value range '0', '1', '4', '2',`DaysToManufacture` IN ('0', '1', '4', '2'),None)) DaysToManufacture
# CompletenessConstraint(Completeness(DaysToManufacture,None)) DaysToManufacture
# ComplianceConstraint(Compliance('DaysToManufacture' has value range '0', '1', '4' for at least 97.0% of values,`DaysToManufacture` IN ('0', '1', '4'),None)) DaysToManufacture
# ComplianceConstraint(Compliance('DaysToManufacture' has no negative values,DaysToManufacture >= 0,None)) DaysToManufacture
# CompletenessConstraint(Completeness(SellStartDate,None)) SellStartDate
# CompletenessConstraint(Completeness(MakeFlag,None)) MakeFlag
# ComplianceConstraint(Compliance('ProductSubcategoryID' has value range '2', '14', '1', '12', '3', '16', '17', '37', '15', '21', '4', '13', '22', '20' for at least 87.0% of values,`ProductSubcategoryID` IN ('2', '14', '1', '12', '3', '16', '17', '37', '15', '21', '4', '13', '22', '20'),None)) ProductSubcategoryID
# ComplianceConstraint(Compliance('ProductSubcategoryID' has no negative values,ProductSubcategoryID >= 0,None)) ProductSubcategoryID
# CompletenessConstraint(Completeness(ProductSubcategoryID,None)) ProductSubcategoryID
# ComplianceConstraint(Compliance('Weight' has no negative values,Weight >= 0,None)) Weight
# CompletenessConstraint(Completeness(Weight,None)) Weight
# ComplianceConstraint(Compliance('WeightUnitMeasureCode' has value range 'LB ', 'G  ',`WeightUnitMeasureCode` IN ('LB ', 'G  '),None)) WeightUnitMeasureCode
# ComplianceConstraint(Compliance('WeightUnitMeasureCode' has value range 'LB ' for at least 92.0% of values,`WeightUnitMeasureCode` IN ('LB '),None)) WeightUnitMeasureCode
# CompletenessConstraint(Completeness(WeightUnitMeasureCode,None)) WeightUnitMeasureCode
# CompletenessConstraint(Completeness(ProductNumber,None)) ProductNumber
# UniquenessConstraint(Uniqueness(List(ProductNumber),None)) ProductNumber
# CompletenessConstraint(Completeness(FinishedGoodsFlag,None)) FinishedGoodsFlag
# ComplianceConstraint(Compliance('Class' has value range 'L ', 'H ', 'M ',`Class` IN ('L ', 'H ', 'M '),None)) Class
# ComplianceConstraint(Compliance('Class' has value range 'L ', 'H ', 'M ' for at least 99.0% of values,`Class` IN ('L ', 'H ', 'M '),None)) Class
# CompletenessConstraint(Completeness(Class,None)) Class
# ComplianceConstraint(Compliance('ProductModelID' has no negative values,ProductModelID >= 0,None)) ProductModelID
# CompletenessConstraint(Completeness(ProductModelID,None)) ProductModelID
# ComplianceConstraint(Compliance('Style' has value range 'U ', 'W ', 'M ',`Style` IN ('U ', 'W ', 'M '),None)) Style
# ComplianceConstraint(Compliance('Style' has value range 'U ' for at least 90.0% of values,`Style` IN ('U '),None)) Style
# CompletenessConstraint(Completeness(Style,None)) Style
# CompletenessConstraint(Completeness(ProductID,None)) ProductID
# ComplianceConstraint(Compliance('ProductID' has no negative values,ProductID >= 0,None)) ProductID
# UniquenessConstraint(Uniqueness(List(ProductID),None)) ProductID
# ComplianceConstraint(Compliance('Color' has value range 'Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black', 'White', 'Grey',`Color` IN ('Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black', 'White', 'Grey'),None)) Color
# ComplianceConstraint(Compliance('Color' has value range 'Black', 'Silver', 'Red', 'Yellow' for at least 88.0% of values,`Color` IN ('Black', 'Silver', 'Red', 'Yellow'),None)) Color
# CompletenessConstraint(Completeness(Color,None)) Color
# CompletenessConstraint(Completeness(StandardCost,None)) StandardCost
# ComplianceConstraint(Compliance('StandardCost' has no negative values,StandardCost >= 0,None)) StandardCost

# %%
# verify constraints
checkResult = VerificationSuite(spark) \
                         .onData(df) \
                         .addCheck(Check(spark, 
                                   CheckLevel.Warning, 
                                   "ProductID check") \
                        .isComplete("ProductID")\
                        .isUnique("ProductID")  \
                        .hasMin("ProductID", lambda x: x >= 0.0)) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Name check") \
                        .isComplete("Name")\
                        .isUnique("Name")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ProductNumber check") \
                        .isComplete("ProductNumber")\
                        .isUnique("ProductNumber")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "MakeFlag check") \
                        .isComplete("MakeFlag")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "FinishedGoodsFlag check") \
                        .isComplete("FinishedGoodsFlag")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Color check") \
                        .isComplete("Color")
                        .isContainedIn("Color", ['Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black', 'White', 'Grey'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "SafetyStockLevel check") \
                        .isComplete("SafetyStockLevel")
                        .hasMin("SafetyStockLevel", lambda x: x >= 0.0) \
                        .isContainedIn("SafetyStockLevel", ['500', '1000', '100', '4', '800', '60'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ReorderPoint check") \
                        .isComplete("ReorderPoint")
                        .hasMin("ReorderPoint", lambda x: x >= 0.0) \
                        .isContainedIn("ReorderPoint", ['375', '750', '75', '3', '600', '45'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "StandardCost check") \
                        .isComplete("StandardCost")
                        .hasMin("StandardCost", lambda x: x >= 0.0)) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ListPrice check") \
                        .isComplete("ListPrice")
                        .hasMin("ListPrice", lambda x: x >= 0.0)) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Size check") \
                        .isComplete("Size")\
                        .isContainedIn("Size", ['44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40', '62', 'S', '54', '50', 'XL', '56', '70'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "SizeUnitMeasureCode check") \
                        .isComplete("SizeUnitMeasureCode")\
                        .isContainedIn("SizeUnitMeasureCode", ['CM '])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "WeightUnitMeasureCode check") \
                        .isComplete("WeightUnitMeasureCode")\
                        .isContainedIn("WeightUnitMeasureCode", ['LB ', 'G  '])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Weight check") \
                        .isComplete("Weight")\
                        .hasMin("Weight", lambda x: x >= 0.0)) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "DaysToManufacture check") \
                        .isComplete("DaysToManufacture")
                        .hasMin("DaysToManufacture", lambda x: x >= 0.0) \
                        .isContainedIn("DaysToManufacture", ['0', '1', '4', '2'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ProductLine check") \
                        .isComplete("ProductLine")\
                        .isContainedIn("ProductLine", ['R ', 'M ', 'T ', 'S '])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Class check") \
                        .isComplete("Class")\
                        .isContainedIn("Class", ['L ', 'H ', 'M '])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "Style check") \
                        .isComplete("Style")\
                        .isContainedIn("Style", ['U ', 'W ', 'M '])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ProductSubcategoryID check") \
                        .isComplete("ProductSubcategoryID")
                        .hasMin("ProductSubcategoryID", lambda x: x >= 0.0) \
                        .isContainedIn("ProductSubcategoryID", ['2', '14', '1', '12', '3', '16', '17', '37', '15', '21', '4', '13', '22', '20'])) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ProductModelID check") \
                        .isComplete("ProductModelID")
                        .hasMin("ProductModelID", lambda x: x >= 0.0)) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "SellStartDate check") \
                        .isComplete("SellStartDate")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "ModifiedDate check") \
                        .isComplete("ModifiedDate")) \
                        .addCheck(Check(spark, 
                                  CheckLevel.Warning, 
                                  "rowguid check") \
                        .isComplete("rowguid")\
                        .isUnique("rowguid")) \
    .run()
checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show(50)
# Out:
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+
# |               check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+
# |WeightUnitMeasure...|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.40674603...|
# |WeightUnitMeasure...|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |ProductModelID check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.58531746...|
# |ProductModelID check|    Warning|     Warning|MinimumConstraint...|          Success|                    |
# |       rowguid check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |       rowguid check|    Warning|     Success|UniquenessConstra...|          Success|                    |
# |  ModifiedDate check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |         Color check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.50793650...|
# |         Color check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |  StandardCost check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |  StandardCost check|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |         Style check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.41865079...|
# |         Style check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |SizeUnitMeasureCo...|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.34920634...|
# |SizeUnitMeasureCo...|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |     ListPrice check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |     ListPrice check|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |     ProductID check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |     ProductID check|    Warning|     Success|UniquenessConstra...|          Success|                    |
# |     ProductID check|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |      MakeFlag check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |        Weight check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.40674603...|
# |        Weight check|    Warning|     Warning|MinimumConstraint...|          Success|                    |
# |SafetyStockLevel ...|    Warning|     Success|CompletenessConst...|          Success|                    |
# |SafetyStockLevel ...|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |SafetyStockLevel ...|    Warning|     Success|ComplianceConstra...|          Success|                    |
# |  ReorderPoint check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |  ReorderPoint check|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |  ReorderPoint check|    Warning|     Success|ComplianceConstra...|          Success|                    |
# |          Size check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.41865079...|
# |          Size check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |         Class check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.49007936...|
# |         Class check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |ProductSubcategor...|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.58531746...|
# |ProductSubcategor...|    Warning|     Warning|MinimumConstraint...|          Success|                    |
# |ProductSubcategor...|    Warning|     Warning|ComplianceConstra...|          Failure|Value: 0.90277777...|
# |          Name check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |          Name check|    Warning|     Success|UniquenessConstra...|          Success|                    |
# | SellStartDate check|    Warning|     Success|CompletenessConst...|          Success|                    |
# |   ProductLine check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.55158730...|
# |   ProductLine check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |FinishedGoodsFlag...|    Warning|     Success|CompletenessConst...|          Success|                    |
# |DaysToManufacture...|    Warning|     Success|CompletenessConst...|          Success|                    |
# |DaysToManufacture...|    Warning|     Success|MinimumConstraint...|          Success|                    |
# |DaysToManufacture...|    Warning|     Success|ComplianceConstra...|          Success|                    |
# | ProductNumber check|    Warning|     Success|CompletenessConst...|          Success|                    |
# | ProductNumber check|    Warning|     Success|UniquenessConstra...|          Success|                    |
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+

# %%
# Convert checkResult_df to a pandas DataFrame and sort it by check
checkResult_df_pd = checkResult_df.toPandas()
checkResult_df_pd = checkResult_df_pd.sort_values(by='check')
# Define the template for the HTML report also some style added for better cheking constraint_status
html_template = """
<!DOCTYPE html>
<html>
<head>
  <title>Verification Result Report</title>
  <style>
    table, th, td {
      border: 1px solid black;
      border-collapse: collapse;
    }
    th, td {
      padding: 5px;
      text-align: left;
    }
    th {
      background-color: #ddd;
    }
    .success {
      color: green;
    }
    .failure {
      color: red;
    }
  </style>
</head>
<body>
  <h1>Verification Result Report</h1>
  <p>{{ num_checks }} checks were performed.</p>
  <table>
    <thead>
      <tr>
        <th>Check</th>
        <th>Check Level</th>
        <th>Check Status</th>
        <th>Constraint</th>
        <th>Constraint Status</th>
        <th>Constraint Message</th>
      </tr>
    </thead>
    <tbody>
      {% for index, row in data.iterrows() %}
        <tr>
          <td>{{ row['check'] }}</td>
          <td>{{ row['check_level'] }}</td>
          <td>{{ row['check_status'] }}</td>
          <td>{{ row['constraint'] }}</td>
          <td class="{% if row['constraint_status'] == 'Success' %}success{% else %}failure{% endif %}">
            {{ row['constraint_status'] }}
          </td>
          <td>{{ row['constraint_message'] }}</td>
        </tr>
      {% endfor %}
    </tbody>
  </table>
</body>
</html>
"""

# Define the variables to render the template
template_vars = {
    'num_checks': len(checkResult_df_pd),
    'data': checkResult_df_pd
}

# Create a jinja2 template object
template = Template(html_template)

# Render the template with the variables
html_report = template.render(template_vars)

# Write the HTML report to a file
with open('verification_report.html', 'w') as f:
    f.write(html_report)
